# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

#df = pd.read_csv("data/^990100-USD-STRD (1).csv")
#df = pd.read_csv("data/^SPX (1).csv")
# 3USL.L.csv
df = pd.read_csv("data/3USL.L.csv")

df = df.dropna(axis=0)

df["Date"] = pd.to_datetime(df["Date"])
df = df[df["Date"] >= "2016-10-08"]
#df.to_csv("data/SP500_Tobi_30j.csv")

df
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 965  2016-10-10  15.980500  15.980500  15.980500  16.237499  16.237499      60
# 966  2016-10-11  16.024500  16.101500  15.650000  15.581250  15.581250     660
# 967  2016-10-12  15.550000  15.585000  15.508500  15.556750  15.556750    1200
# 968  2016-10-13  15.277000  15.277000  15.234000  15.261750  15.261750   14200
# 969  2016-10-14  15.761000  15.761000  15.746000  15.568250  15.568250    1560
# ...         ...        ...        ...        ...        ...        ...     ...
# 2843 2024-03-18  83.970001  86.050003  83.970001  85.574997  85.574997    5244
# 2844 2024-03-19  84.669998  85.339996  83.739998  85.489998  85.489998     379
# 2845 2024-03-20  86.150002  86.639999  86.150002  86.330002  86.330002    5194
# 2846 2024-03-21  90.019997  90.389999  89.500000  90.379997  90.379997    6704
# 2847 2024-03-22  89.529999  89.900002  89.000000  89.019997  89.019997    2444
#
# [1883 rows x 7 columns]

# %%
def calc_returns(prices):
    returns = [0]
    counter = len(prices)
    for i in range(1, counter):
        ret = prices[i] / prices[i-1] - 1
        returns.append(ret)
    return returns

def x_to_y(x, y):
    x2y = []
    for i in range(len(x)):
        x2y.append(y[i] / x[i] - 1)
    return x2y


df["daily_movement_1x"] = calc_returns(df["Adj Close"].to_list())
df["daily_movement_2x"] = df["daily_movement_1x"] * 2
df["daily_movement_3x"] = df["daily_movement_1x"] * 3

df["open_to_low_1x"] = x_to_y(df["Open"].to_list(), df["Low"].to_list())
df["open_to_high_1x"] = x_to_y(df["Open"].to_list(), df["High"].to_list())
df["adj_close_to_open_1x"] = x_to_y(df["Adj Close"].to_list(), df["Open"].to_list())
df["open_to_low_2x"] = df["open_to_low_1x"] * 2
df["open_to_high_2x"] = df["open_to_high_1x"] * 2
df["adj_close_to_open_2x"] = df["adj_close_to_open_1x"] * 2
df["open_to_low_3x"] = df["open_to_low_1x"] * 3
df["open_to_high_3x"] = df["open_to_high_1x"] * 3
df["adj_close_to_open_3x"] = df["adj_close_to_open_1x"] * 3

df
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 965  2016-10-10  15.980500  15.980500  15.980500  16.237499  16.237499  \
# 966  2016-10-11  16.024500  16.101500  15.650000  15.581250  15.581250
# 967  2016-10-12  15.550000  15.585000  15.508500  15.556750  15.556750
# 968  2016-10-13  15.277000  15.277000  15.234000  15.261750  15.261750
# 969  2016-10-14  15.761000  15.761000  15.746000  15.568250  15.568250
# ...         ...        ...        ...        ...        ...        ...
# 2843 2024-03-18  83.970001  86.050003  83.970001  85.574997  85.574997
# 2844 2024-03-19  84.669998  85.339996  83.739998  85.489998  85.489998
# 2845 2024-03-20  86.150002  86.639999  86.150002  86.330002  86.330002
# 2846 2024-03-21  90.019997  90.389999  89.500000  90.379997  90.379997
# 2847 2024-03-22  89.529999  89.900002  89.000000  89.019997  89.019997
#
#       Volume  daily_movement_1x  daily_movement_2x  daily_movement_3x
# 965       60           0.000000           0.000000           0.000000  \
# 966      660          -0.040416          -0.080831          -0.121247
# 967     1200          -0.001572          -0.003145          -0.004717
# 968    14200          -0.018963          -0.037926          -0.056888
# 969     1560           0.020083           0.040166           0.060249
# ...      ...                ...                ...                ...
# 2843    5244           0.029288           0.058576           0.087864
# 2844     379          -0.000993          -0.001987          -0.002980
# 2845    5194           0.009826           0.019652           0.029477
# 2846    6704           0.046913           0.093826           0.140739
# 2847    2444          -0.015048          -0.030095          -0.045143
#
#       open_to_low_1x  open_to_high_1x  adj_close_to_open_1x  open_to_low_2x
# 965         0.000000         0.000000             -0.015827        0.000000  \
# 966        -0.023370         0.004805              0.028448       -0.046741
# 967        -0.002669         0.002251             -0.000434       -0.005338
# 968        -0.002815         0.000000              0.000999       -0.005629
# 969        -0.000952         0.000000              0.012381       -0.001903
# ...              ...              ...                   ...             ...
# 2843        0.000000         0.024771             -0.018755        0.000000
# 2844       -0.010984         0.007913             -0.009592       -0.021968
# 2845        0.000000         0.005688             -0.002085        0.000000
# 2846       -0.005776         0.004110             -0.003983       -0.011553
# 2847       -0.005920         0.004133              0.005729       -0.011840
#
#       open_to_high_2x  adj_close_to_open_2x  open_to_low_3x  open_to_high_3x
# 965          0.000000             -0.031655        0.000000         0.000000  \
# 966          0.009610              0.056895       -0.070111         0.014415
# 967          0.004502             -0.000868       -0.008006         0.006752
# 968          0.000000              0.001998       -0.008444         0.000000
# 969          0.000000              0.024762       -0.002855         0.000000
# ...               ...                   ...             ...              ...
# 2843         0.049542             -0.037511        0.000000         0.074312
# 2844         0.015826             -0.019184       -0.032951         0.023739
# 2845         0.011375             -0.004170        0.000000         0.017063
# 2846         0.008220             -0.007966       -0.017329         0.012331
# 2847         0.008265              0.011458       -0.017759         0.012398
#
#       adj_close_to_open_3x
# 965              -0.047482
# 966               0.085343
# 967              -0.001302
# 968               0.002998
# 969               0.037143
# ...                    ...
# 2843             -0.056266
# 2844             -0.028775
# 2845             -0.006255
# 2846             -0.011950
# 2847              0.017187
#
# [1883 rows x 19 columns]

# %%
# cum returns
def cum_returns(returns):
    cum_returns = [1]
    counter = len(returns)
    for i in range(1, counter):
        ret = (returns[i] + 1) * cum_returns[i-1]
        cum_returns.append(ret)
    return cum_returns

df["cum_return_1x"] = cum_returns(df["daily_movement_1x"].to_list())
df["cum_return_2x"] = cum_returns(df["daily_movement_2x"].to_list())
df["cum_return_3x"] = cum_returns(df["daily_movement_3x"].to_list())
df
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 965  2016-10-10  15.980500  15.980500  15.980500  16.237499  16.237499  \
# 966  2016-10-11  16.024500  16.101500  15.650000  15.581250  15.581250
# 967  2016-10-12  15.550000  15.585000  15.508500  15.556750  15.556750
# 968  2016-10-13  15.277000  15.277000  15.234000  15.261750  15.261750
# 969  2016-10-14  15.761000  15.761000  15.746000  15.568250  15.568250
# ...         ...        ...        ...        ...        ...        ...
# 2843 2024-03-18  83.970001  86.050003  83.970001  85.574997  85.574997
# 2844 2024-03-19  84.669998  85.339996  83.739998  85.489998  85.489998
# 2845 2024-03-20  86.150002  86.639999  86.150002  86.330002  86.330002
# 2846 2024-03-21  90.019997  90.389999  89.500000  90.379997  90.379997
# 2847 2024-03-22  89.529999  89.900002  89.000000  89.019997  89.019997
#
#       Volume  daily_movement_1x  daily_movement_2x  daily_movement_3x
# 965       60           0.000000           0.000000           0.000000  \
# 966      660          -0.040416          -0.080831          -0.121247
# 967     1200          -0.001572          -0.003145          -0.004717
# 968    14200          -0.018963          -0.037926          -0.056888
# 969     1560           0.020083           0.040166           0.060249
# ...      ...                ...                ...                ...
# 2843    5244           0.029288           0.058576           0.087864
# 2844     379          -0.000993          -0.001987          -0.002980
# 2845    5194           0.009826           0.019652           0.029477
# 2846    6704           0.046913           0.093826           0.140739
# 2847    2444          -0.015048          -0.030095          -0.045143
#
#       open_to_low_1x  open_to_high_1x  adj_close_to_open_1x  open_to_low_2x
# 965         0.000000         0.000000             -0.015827        0.000000  \
# 966        -0.023370         0.004805              0.028448       -0.046741
# 967        -0.002669         0.002251             -0.000434       -0.005338
# 968        -0.002815         0.000000              0.000999       -0.005629
# 969        -0.000952         0.000000              0.012381       -0.001903
# ...              ...              ...                   ...             ...
# 2843        0.000000         0.024771             -0.018755        0.000000
# 2844       -0.010984         0.007913             -0.009592       -0.021968
# 2845        0.000000         0.005688             -0.002085        0.000000
# 2846       -0.005776         0.004110             -0.003983       -0.011553
# 2847       -0.005920         0.004133              0.005729       -0.011840
#
#       open_to_high_2x  adj_close_to_open_2x  open_to_low_3x  open_to_high_3x
# 965          0.000000             -0.031655        0.000000         0.000000  \
# 966          0.009610              0.056895       -0.070111         0.014415
# 967          0.004502             -0.000868       -0.008006         0.006752
# 968          0.000000              0.001998       -0.008444         0.000000
# 969          0.000000              0.024762       -0.002855         0.000000
# ...               ...                   ...             ...              ...
# 2843         0.049542             -0.037511        0.000000         0.074312
# 2844         0.015826             -0.019184       -0.032951         0.023739
# 2845         0.011375             -0.004170        0.000000         0.017063
# 2846         0.008220             -0.007966       -0.017329         0.012331
# 2847         0.008265              0.011458       -0.017759         0.012398
#
#       adj_close_to_open_3x  cum_return_1x  cum_return_2x  cum_return_3x
# 965              -0.047482       1.000000       1.000000       1.000000
# 966               0.085343       0.959584       0.919169       0.878753
# 967              -0.001302       0.958076       0.916278       0.874608
# 968               0.002998       0.939908       0.881528       0.824853
# 969               0.037143       0.958784       0.916935       0.874549
# ...                    ...            ...            ...            ...
# 2843             -0.056266       5.270208    -120.800949     -21.197449
# 2844             -0.028775       5.264973    -120.560974     -21.134285
# 2845             -0.006255       5.316706    -122.930180     -21.757266
# 2846             -0.011950       5.566128    -134.464214     -24.819358
# 2847              0.017187       5.482371    -130.417493     -23.698944
#
# [1883 rows x 22 columns]

# %%
# visual
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objects as go
#df[["Date", "cum_return", "cum_return_2x", "cum_return_3x"]].set_index("Date").plot()


fig = px.line(df, x="Date", y=["cum_return", "cum_return_2x", "cum_return_3x"])
fig.write_html('figures/first_figure.html', auto_open=True)

# %%
# adj close
df["adj_close_2x"] = df["cum_return_2x"] * df["Adj Close"].to_list()[0]
df["adj_close_3x"] = df["cum_return_3x"] * df["Adj Close"].to_list()[0]
df["adj_close_1x"] = df["cum_return_1x"] * df["Adj Close"].to_list()[0]
df
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 965  2016-10-10  15.980500  15.980500  15.980500  16.237499  16.237499  \
# 966  2016-10-11  16.024500  16.101500  15.650000  15.581250  15.581250
# 967  2016-10-12  15.550000  15.585000  15.508500  15.556750  15.556750
# 968  2016-10-13  15.277000  15.277000  15.234000  15.261750  15.261750
# 969  2016-10-14  15.761000  15.761000  15.746000  15.568250  15.568250
# ...         ...        ...        ...        ...        ...        ...
# 2843 2024-03-18  83.970001  86.050003  83.970001  85.574997  85.574997
# 2844 2024-03-19  84.669998  85.339996  83.739998  85.489998  85.489998
# 2845 2024-03-20  86.150002  86.639999  86.150002  86.330002  86.330002
# 2846 2024-03-21  90.019997  90.389999  89.500000  90.379997  90.379997
# 2847 2024-03-22  89.529999  89.900002  89.000000  89.019997  89.019997
#
#       Volume  daily_movement_1x  daily_movement_2x  daily_movement_3x
# 965       60           0.000000           0.000000           0.000000  \
# 966      660          -0.040416          -0.080831          -0.121247
# 967     1200          -0.001572          -0.003145          -0.004717
# 968    14200          -0.018963          -0.037926          -0.056888
# 969     1560           0.020083           0.040166           0.060249
# ...      ...                ...                ...                ...
# 2843    5244           0.029288           0.058576           0.087864
# 2844     379          -0.000993          -0.001987          -0.002980
# 2845    5194           0.009826           0.019652           0.029477
# 2846    6704           0.046913           0.093826           0.140739
# 2847    2444          -0.015048          -0.030095          -0.045143
#
#       open_to_low_1x  open_to_high_1x  adj_close_to_open_1x  open_to_low_2x
# 965         0.000000         0.000000             -0.015827        0.000000  \
# 966        -0.023370         0.004805              0.028448       -0.046741
# 967        -0.002669         0.002251             -0.000434       -0.005338
# 968        -0.002815         0.000000              0.000999       -0.005629
# 969        -0.000952         0.000000              0.012381       -0.001903
# ...              ...              ...                   ...             ...
# 2843        0.000000         0.024771             -0.018755        0.000000
# 2844       -0.010984         0.007913             -0.009592       -0.021968
# 2845        0.000000         0.005688             -0.002085        0.000000
# 2846       -0.005776         0.004110             -0.003983       -0.011553
# 2847       -0.005920         0.004133              0.005729       -0.011840
#
#       open_to_high_2x  adj_close_to_open_2x  open_to_low_3x  open_to_high_3x
# 965          0.000000             -0.031655        0.000000         0.000000  \
# 966          0.009610              0.056895       -0.070111         0.014415
# 967          0.004502             -0.000868       -0.008006         0.006752
# 968          0.000000              0.001998       -0.008444         0.000000
# 969          0.000000              0.024762       -0.002855         0.000000
# ...               ...                   ...             ...              ...
# 2843         0.049542             -0.037511        0.000000         0.074312
# 2844         0.015826             -0.019184       -0.032951         0.023739
# 2845         0.011375             -0.004170        0.000000         0.017063
# 2846         0.008220             -0.007966       -0.017329         0.012331
# 2847         0.008265              0.011458       -0.017759         0.012398
#
#       adj_close_to_open_3x  cum_return_1x  cum_return_2x  cum_return_3x
# 965              -0.047482       1.000000       1.000000       1.000000  \
# 966               0.085343       0.959584       0.919169       0.878753
# 967              -0.001302       0.958076       0.916278       0.874608
# 968               0.002998       0.939908       0.881528       0.824853
# 969               0.037143       0.958784       0.916935       0.874549
# ...                    ...            ...            ...            ...
# 2843             -0.056266       5.270208    -120.800949     -21.197449
# 2844             -0.028775       5.264973    -120.560974     -21.134285
# 2845             -0.006255       5.316706    -122.930180     -21.757266
# 2846             -0.011950       5.566128    -134.464214     -24.819358
# 2847              0.017187       5.482371    -130.417493     -23.698944
#
#       adj_close_2x  adj_close_3x  adj_close_1x
# 965      16.237499     16.237499     16.237499
# 966      14.925001     14.268752     15.581250
# 967      14.878065     14.201443     15.556750
# 968      14.313804     13.393545     15.261750
# 969      14.888729     14.200488     15.568250
# ...            ...           ...           ...
# 2843  -1961.505296   -344.193555     85.574997
# 2844  -1957.608690   -343.167924     85.489998
# 2845  -1996.078668   -353.283579     86.330002
# 2846  -2183.362542   -403.004303     90.379997
# 2847  -2117.653908   -384.811587     89.019997
#
# [1883 rows x 25 columns]

# %%
# visual
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objects as go

fig = px.line(df, x="Date", y=["adj_close", "adj_close_2x", "adj_close_3x"])
fig.write_html('figures/first_figure0.html', auto_open=True)

# %%
# moving average
from statistics import mean

def moving_average(data, days):
    avg = [np.NaN] * days
    data = data.to_list()
    
    for i in range(days, len(data)):
        subset = data[i-days:i]
        avg.append(mean(subset))

    return avg

#df["mavg_300_adj_close"] = moving_average(df.adj_close, 300)
#df["mavg_300_adj_close_2x"] = moving_average(df.adj_close_2x, 300)
#df["mavg_300_adj_close_3x"] = moving_average(df.adj_close_3x, 300)
df["mavg_200_adj_close_1x"] = moving_average(df.adj_close_1x, 200)
df["mavg_200_adj_close_2x"] = moving_average(df.adj_close_2x, 200)
df["mavg_200_adj_close_3x"] = moving_average(df.adj_close_3x, 200)
df["mavg_100_adj_close_1x"] = moving_average(df.adj_close_1x, 100)
df["mavg_100_adj_close_2x"] = moving_average(df.adj_close_2x, 100)
df["mavg_100_adj_close_3x"] = moving_average(df.adj_close_3x, 100)
df.dropna(axis=0)
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 1165 2017-07-26  23.982500  23.982500  23.982500  23.982500  23.982500  \
# 1166 2017-07-27  24.028749  24.028749  24.028749  24.028749  24.028749
# 1167 2017-07-28  23.670000  23.670000  23.670000  23.670000  23.670000
# 1168 2017-07-31  23.875000  23.875000  23.875000  23.784500  23.784500
# 1169 2017-08-01  23.840000  23.840000  23.840000  23.789749  23.789749
# ...         ...        ...        ...        ...        ...        ...
# 2843 2024-03-18  83.970001  86.050003  83.970001  85.574997  85.574997
# 2844 2024-03-19  84.669998  85.339996  83.739998  85.489998  85.489998
# 2845 2024-03-20  86.150002  86.639999  86.150002  86.330002  86.330002
# 2846 2024-03-21  90.019997  90.389999  89.500000  90.379997  90.379997
# 2847 2024-03-22  89.529999  89.900002  89.000000  89.019997  89.019997
#
#       Volume  daily_movement_1x  daily_movement_2x  daily_movement_3x
# 1165       0          -0.002641          -0.005282          -0.007922  \
# 1166       0           0.001928           0.003857           0.005785
# 1167       0          -0.014930          -0.029860          -0.044790
# 1168     500           0.004837           0.009675           0.014512
# 1169    3440           0.000221           0.000441           0.000662
# ...      ...                ...                ...                ...
# 2843    5244           0.029288           0.058576           0.087864
# 2844     379          -0.000993          -0.001987          -0.002980
# 2845    5194           0.009826           0.019652           0.029477
# 2846    6704           0.046913           0.093826           0.140739
# 2847    2444          -0.015048          -0.030095          -0.045143
#
#       open_to_low_1x  open_to_high_1x  adj_close_to_open_1x  open_to_low_2x
# 1165        0.000000         0.000000              0.000000        0.000000  \
# 1166        0.000000         0.000000              0.000000        0.000000
# 1167        0.000000         0.000000              0.000000        0.000000
# 1168        0.000000         0.000000              0.003805        0.000000
# 1169        0.000000         0.000000              0.002112        0.000000
# ...              ...              ...                   ...             ...
# 2843        0.000000         0.024771             -0.018755        0.000000
# 2844       -0.010984         0.007913             -0.009592       -0.021968
# 2845        0.000000         0.005688             -0.002085        0.000000
# 2846       -0.005776         0.004110             -0.003983       -0.011553
# 2847       -0.005920         0.004133              0.005729       -0.011840
#
#       open_to_high_2x  adj_close_to_open_2x  open_to_low_3x  open_to_high_3x
# 1165         0.000000              0.000000        0.000000         0.000000  \
# 1166         0.000000              0.000000        0.000000         0.000000
# 1167         0.000000              0.000000        0.000000         0.000000
# 1168         0.000000              0.007610        0.000000         0.000000
# 1169         0.000000              0.004225        0.000000         0.000000
# ...               ...                   ...             ...              ...
# 2843         0.049542             -0.037511        0.000000         0.074312
# 2844         0.015826             -0.019184       -0.032951         0.023739
# 2845         0.011375             -0.004170        0.000000         0.017063
# 2846         0.008220             -0.007966       -0.017329         0.012331
# 2847         0.008265              0.011458       -0.017759         0.012398
#
#       adj_close_to_open_3x  cum_return_1x  cum_return_2x  cum_return_3x
# 1165              0.000000       1.476982     -70.666561    -291.917301  \
# 1166              0.000000       1.479831     -70.939115    -293.606142
# 1167              0.000000       1.457737     -68.820874    -280.455531
# 1168              0.011415       1.464788     -69.486695    -284.525513
# 1169              0.006337       1.465112     -69.517365    -284.713889
# ...                    ...            ...            ...            ...
# 2843             -0.056266       5.270208    -120.800949     -21.197449
# 2844             -0.028775       5.264973    -120.560974     -21.134285
# 2845             -0.006255       5.316706    -122.930180     -21.757266
# 2846             -0.011950       5.566128    -134.464214     -24.819358
# 2847              0.017187       5.482371    -130.417493     -23.698944
#
#       adj_close_2x  adj_close_3x  adj_close_1x  mavg_200_adj_close_1x
# 1165  -1147.448218  -4740.006875     23.982500              24.127604  \
# 1166  -1151.873806  -4767.429443     24.028749              24.166329
# 1167  -1117.478876  -4553.896411     23.670000              24.208567
# 1168  -1128.290142  -4619.982740     23.784500              24.249133
# 1169  -1128.788146  -4623.041492     23.789749              24.291747
# ...            ...           ...           ...                    ...
# 2843  -1961.505296   -344.193555     85.574997              63.477550
# 2844  -1957.608690   -343.167924     85.489998              63.635750
# 2845  -1996.078668   -353.283579     86.330002              63.792975
# 2846  -2183.362542   -403.004303     90.379997              63.953700
# 2847  -2117.653908   -384.811587     89.019997              64.131725
#
#       mavg_200_adj_close_2x  mavg_200_adj_close_3x  mavg_100_adj_close_1x
# 1165             -73.438109            -374.260633              30.471056  \
# 1166             -79.256538            -398.041855              30.495229
# 1167             -85.090532            -421.950346              30.522564
# 1168             -90.752317            -444.790835              30.548004
# 1169             -96.465336            -467.957717              30.575104
# ...                     ...                    ...                    ...
# 2843           -1146.519746            -167.273758              68.889300
# 2844           -1152.088268            -168.439804              69.252900
# 2845           -1157.620017            -169.597327              69.638800
# 2846           -1163.322064            -170.801090              70.033900
# 2847           -1169.867360            -172.235076              70.472550
#
#       mavg_100_adj_close_2x  mavg_100_adj_close_3x
# 1165            -166.323278            -769.722996
# 1166            -178.078857            -817.482744
# 1167            -189.871653            -865.503207
# 1168            -201.316143            -911.380087
# 1169            -212.867431            -957.915358
# ...                     ...                    ...
# 2843           -1321.526339            -200.517889
# 2844           -1334.384701            -203.221184
# 2845           -1347.839744            -206.018457
# 2846           -1361.700371            -208.920133
# 2847           -1377.513313            -212.331351
#
# [1683 rows x 31 columns]

# %%
# visual
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objects as go

fig = px.line(df, x="Date", y=[
    "adj_close_3x",
    "mavg_100_adj_close_3x",
    "mavg_200_adj_close_3x"
])
fig.write_html('figures/first_figure2.html', auto_open=True)

# %%
"""
Investment Strategy: Sell when Low is below mavg, buy when High is above mavg. Buy and Sell at mavg price --- 1x
"""

df = df.dropna(axis=0)

def apply_strategy(df, leverage, start_amount, ter, tax=0.25*0.7, transaction_cost=1, spread=0.02):
    operations = ["buy"]
    operations_balance = [start_amount]
    balance = []
    buys = {"buy": [], "index": []}
    sells = {"sell": [], "index": []}
    adj_close = df[f"adj_close_{leverage}x"].to_list()
    mavg = df[f"mavg_200_adj_close_{leverage}x"].to_list()
    returns = df[f"daily_movement_{leverage}x"].to_list()
    open_to_low = df[f"open_to_low_{leverage}x"].to_list()
    open_to_high = df[f"open_to_high_{leverage}x"].to_list()
    adj_close_to_open = df[f"adj_close_to_open_{leverage}x"].to_list()
    lows = df["Low"].to_list()
    highs = df["High"].to_list()
    opens = df["Open"].to_list()
    
    for i in range(len(adj_close)):
        # calculate open, low and high
        #open = adj_close[i] * (1 + adj_close_to_open[i])
        #low = open * (1 + open_to_low[i])
        #high = open * (1 + open_to_high[i])
        open = opens[i]
        low = lows[i]
        high = highs[i]
        
        # claculate return for the day if in the market
        if operations[-1] == "buy":
            # if low below mavg, only calculate loss from open to mavg
            if low < mavg[i]:
                start_amount = start_amount * (1 + returns[i]*1)
            else:
                start_amount = start_amount * (1 + returns[i])

        #print("high:", high, "low:", low, "adj close:", adj_close[i], "mavg:", mavg[i], "balance:", start_amount)

        # buy, if not in the market and adj close price rises above avg
        if high > mavg[i] and operations[-1] != "buy":
            #print(adj_close[i]/mavg[i]-1, ",", sep="")
            operations.append("buy")
            start_amount = start_amount * (1 + returns[i]*1)
            # capture buy price
            operations_balance.append(mavg[i])
            # transaction_cost
            start_amount = start_amount - transaction_cost
            # save buy
            buys["buy"].append(adj_close[i])
            buys["index"].append(i)
        # sell, if in the maket and dj close price falls below avg
        elif low < mavg[i] * 0.5 and operations[-1] != "sell":
            #print(adj_close[i]/(mavg[i]*0.8)-1, ",", sep="")
            operations.append("sell")
            #start_amount = start_amount / (1 + returns[i]) * (adj_close[i] < mavg[i])
            # tax
            if start_amount > operations_balance[-1]:
                start_amount = start_amount - (start_amount - operations_balance[-1]) * tax
            # spread
            start_amount = start_amount * (1 - spread)
            # transaction_cost
            start_amount = start_amount - transaction_cost
            # save sell
            sells["sell"].append(adj_close[i])
            sells["index"].append(i)

        # TER
        if i % 200 == 0:
            start_amount = start_amount * (1 - ter)

        balance.append(start_amount)

    print("-----------------------")
    print(len(operations))
    print(start_amount)
    return balance, buys, sells
        
amount = df["adj_close_1x"].to_list()[0]
balance_200, _, sells = apply_strategy(df=df, leverage=1, start_amount=amount, ter=0.0075)

comp = pd.DataFrame({"avg 200": balance_200})
comp = comp.reset_index()
comp["date"] = df["Date"].to_list()
comp["mavg_200_adj_close_1x"] = df["mavg_200_adj_close_1x"].to_list() #/ df["adj_close_3x"].to_list()[0] * amount
comp["mavg_200_adj_close_1x_factor"] = df["mavg_200_adj_close_1x"] / df["adj_close_3x"].to_list()[0] * amount
#comp["adj_close_3x"] = df["adj_close_3x"].to_list()
comp["adj_close_1x"] = df["adj_close_1x"].to_list()
comp = comp.reset_index()

fig = px.line(comp, x="index", y=["avg 200", "adj_close_1x", "mavg_200_adj_close_1x", "mavg_200_adj_close_1x_factor"])
fig = fig.add_scatter(x=_["index"], y=_["buy"], mode="markers")
fig = fig.add_scatter(x=sells["index"], y=sells["sell"], mode="markers")
fig.update_traces(marker=dict(size=10))
fig.write_html('figures/first_figure4.html', auto_open=True)

print(balance_200[-1]/ balance_200[0])
print(pow(balance_200[-1]/balance_200[0], 1/30))

comp.astype(str)


#23 41
# Out:
# -----------------------
# 3
# 43.56284062710893
# 1.835014973314051
# 1.0204412053578118
#      level_0 index             avg 200        date mavg_200_adj_close_1x
# 0          0     0  23.739773931345155  2017-07-26    24.127604460000015  \
# 1          1     1  23.785554846785615  2017-07-27    24.166329465000015
# 2          2     2  23.430436733240484  2017-07-28    24.208566960000013
# 3          3     3   23.54377788262604  2017-07-31    24.249133210000014
# 4          4     4   23.54897375767516  2017-08-01    24.291746960000015
# ...      ...   ...                 ...         ...                   ...
# 1678    1678  1678   41.87699485067747  2024-03-18    63.477549990000036
# 1679    1679  1679  41.835399725815094  2024-03-19    63.635749970000035
# 1680    1680  1680   42.24646422380799  2024-03-20     63.79297497000003
# 1681    1681  1681   44.22837045466968  2024-03-21    63.953699975000035
# 1682    1682  1682   43.56284062710893  2024-03-22     64.13172495000003
#
#      mavg_200_adj_close_1x_factor        adj_close_1x
# 0                             nan   23.98250000000002
# 1                             nan   24.02874900000002
# 2                             nan   23.67000000000002
# 3                             nan  23.784500000000023
# 4                             nan   23.78974900000002
# ...                           ...                 ...
# 1678          -0.1546848899979601   85.57499700000004
# 1679          -0.1546813735816471   85.48999800000003
# 1680         -0.15469382650200736   86.33000200000002
# 1681         -0.15480301244282796   90.37999700000005
# 1682         -0.15490266740286074   89.01999700000005
#
# [1683 rows x 7 columns]

# %%
"""
Investment Strategy: Sell when Low is below mavg, buy when High is above mavg. Buy and Sell at mavg price
"""

df = df.dropna(axis=0)

def apply_strategy(df, leverage, start_amount, ter, tax=0.25*0.7, transaction_cost=1, spread=0.02):
    operations = ["buy"]
    operations_balance = [start_amount]
    balance = []
    buys = {"buy": [], "index": []}
    sells = {"sell": [], "index": []}
    adj_close = df[f"adj_close_{leverage}x"].to_list()
    mavg = df[f"mavg_200_adj_close_{leverage}x"].to_list()
    returns = df[f"daily_movement_{leverage}x"].to_list()
    open_to_low = df[f"open_to_low_{leverage}x"].to_list()
    open_to_high = df[f"open_to_high_{leverage}x"].to_list()
    adj_close_to_open = df[f"adj_close_to_open_{leverage}x"].to_list()
    
    for i in range(len(adj_close)):
        # calculate open, low and high
        open = adj_close[i] * (1 + adj_close_to_open[i])
        low = open * (1 + open_to_low[i])
        high = open * (1 + open_to_high[i])
        
        # claculate return for the day if in the market
        if operations[-1] == "buy":
            # if low below mavg, only calculate loss from open to mavg
            if low < mavg[i]:
                start_amount = start_amount * (1 + returns[i]*1)
            else:
                start_amount = start_amount * (1 + returns[i])

        #print("high:", high, "low:", low, "adj close:", adj_close[i], "mavg:", mavg[i], "balance:", start_amount)

        # buy, if not in the market and adj close price rises above avg
        if high > mavg[i] and operations[-1] != "buy":
            #print(adj_close[i]/mavg[i]-1, ",", sep="")
            operations.append("buy")
            start_amount = start_amount * (1 + returns[i]*1)
            # capture buy price
            operations_balance.append(mavg[i])
            # transaction_cost
            start_amount = start_amount - transaction_cost
            # save buy
            buys["buy"].append(adj_close[i])
            buys["index"].append(i)
        # sell, if in the maket and dj close price falls below avg
        elif low < mavg[i] * 0.8 and operations[-1] != "sell":
            #print(adj_close[i]/(mavg[i]*0.8)-1, ",", sep="")
            operations.append("sell")
            #start_amount = start_amount / (1 + returns[i]) * (adj_close[i] < mavg[i])
            # tax
            if start_amount > operations_balance[-1]:
                start_amount = start_amount - (start_amount - operations_balance[-1]) * tax
            # spread
            start_amount = start_amount * (1 - spread)
            # transaction_cost
            start_amount = start_amount - transaction_cost
            # save sell
            sells["sell"].append(adj_close[i])
            sells["index"].append(i)

        # TER
        if i % 200 == 0:
            start_amount = start_amount * (1 - ter)

        balance.append(start_amount)

    print("-----------------------")
    print(len(operations))
    print(start_amount)
    return balance, buys, sells
        
amount = df["adj_close_1x"].to_list()[0]
balance_200, _, sells = apply_strategy(df=df, leverage=3, start_amount=amount, ter=0.0075)

comp = pd.DataFrame({"avg 200": balance_200})
comp = comp.reset_index()
comp["date"] = df["Date"].to_list()
comp["mavg_200_adj_close_3x"] = df["mavg_200_adj_close_3x"].to_list() #/ df["adj_close_3x"].to_list()[0] * amount
comp["mavg_200_adj_close_3x"] = comp["mavg_200_adj_close_3x"] / df["adj_close_3x"].to_list()[0] * amount
comp["adj_close_3x"] = df["adj_close_3x"].to_list()
comp["adj_close_1x"] = df["adj_close_1x"].to_list()
comp = comp.reset_index()

fig = px.line(comp, x="index", y=["avg 200", "mavg_200_adj_close_3x", "adj_close_3x", "adj_close_1x"])
fig = fig.add_scatter(x=_["index"], y=_["buy"], mode="markers")
fig = fig.add_scatter(x=sells["index"], y=sells["sell"], mode="markers")
fig.update_traces(marker=dict(size=10))
fig.write_html('figures/first_figure4.html', auto_open=True)

print(balance_200[-1]/ balance_200[0])
print(pow(balance_200[-1]/balance_200[0], 1/30))

comp.astype(str)


#1900 3300
# Out:
# -----------------------
# 7
# 5848.940357614968
# 3.001342851837024
# 1.0373146710569614
#      level_0 index             avg 200        date mavg_200_adj_close_3x
# 0          0     0  1948.7744807411864  2017-07-31    1600.2955223843016  \
# 1          1     1  1976.4992725935142  2017-08-01      1603.64374872961
# 2          2     2  1976.1984191946551  2017-08-02    1607.1861636061517
# 3          3     3  1971.3837548397091  2017-08-03     1610.793904116692
# 4          4     4  1968.6803685016637  2017-08-04    1614.3312961753304
# ...      ...   ...                 ...         ...                   ...
# 1654    1654  1654   5774.923912061946  2024-02-28     4019.939953790773
# 1655    1655  1655   5851.050774502936  2024-02-29    4029.9436613917956
# 1656    1656  1656  5992.0148609471835  2024-03-01     4040.607832752865
# 1657    1657  1657   5982.930914762687  2024-03-04    4051.5998434928642
# 1658    1658  1658   5848.940357614968  2024-03-05    4062.2051988951275
#
#             adj_close_3x        adj_close_1x
# 0      2581.939860044986  1961.0999760000018
# 1        2618.6725584164  1970.4000240000016
# 2      2618.273956428217  1970.3000490000018
# 3      2611.894986499359  1968.6999510000019
# 4     2608.3132580786105  1967.8000490000015
# ...                  ...                 ...
# 1654   7070.048767043718   3322.600098000008
# 1655   7163.248372464606  3337.1999510000082
# 1656   7335.826051536874  3364.0000000000086
# 1657   7324.704876002865  3362.3000490000086
# 1658   7160.664658714618  3337.1999510000087
#
# [1659 rows x 7 columns]

# %%
buy = [0.01902456140658937,
0.023921858855936007,
-0.009610158513005396,
0.023619477868030092,
0.0023717611005305006,
-0.04523143484391223,
0.013761359695142472,
-0.01780350728578295,
0.004124804866382004,
-0.0004893179161492567,
-0.0050990860030094565,
-0.08350118995494071,
0.0020846373306246946,
0.0020350175378183177,
0.009567519063300667]

sell = [-0.13289314875135405,
0.049690210669110835,
0.0026513025059928808,
0.002534877679760017,
0.023469621584752298,
0.10011032871439829,
-0.030846949733219442,
-0.019121919214916017,
-0.07828236785774023,
0.007905865241265797,
0.05297711300821262,
0.10058843633334047,
-0.1524216436239918,
0.07490512064452015,
0.04229404306215345,]

from statistics import mean
print(mean(buy))
print(mean(sell))
# Out:
# -0.004081579786163058
# 0.002904059350819018
